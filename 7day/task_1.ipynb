# %% [markdown]
# <a href="https://colab.research.google.com/github/HHJina/oz_python/blob/main/task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter33 ~ 41 수업은 잘 들으셨나요?
#
# Chapter33 ~ 41의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제 1]
#
# 사용자로부터 두 개의 숫자를 입력받아 나눗셈을 수행하는 프로그램을 작성하세요.
#
# [예외처리]
# - 입력 값이 숫자가 아닐 때 발생할 수 있는 ValueError
# - 나누는 수가 0일 때 발생할 수 있는 ZeroDivisionError
# - 위 2가지 예외처리 후 사용자에게 이해하기 쉬운 메시지 작성 후 출력되도록 코드를 작성

# %%
try:
    a, b = map(int, input().split(','))
    print(a / b)
except ValueError:
    print('숫자를 입력하세요')
except ZeroDivisionError:
    print('0으로 나눌 순 없습니다')
except:
    print('잘못 입력된 값입니다')
# Out:
# 2,0
# 0을 나눌 순 없습니다

# %% [markdown]
# ---

# %% [markdown]
# [문제 2]
#
# 파일을 읽어서 내용을 출력하는 프로그램을 작성하세요.
#
# - 파일이 존재하지 않을 때 발생하는 FileNotFoundError를 처리
# - 파일이 존재하지 않을 경우 "파일을 찾을 수 없습니다."라는 메시지를 출력

# %%
try:
    with open("testa.txt", "r") as f:
        data = f.read()

    print(data)
except FileNotFoundError:
    print('파일을 찾을 수 없습니다.')
# Out:
# 파일을 찾을 수 없습니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제 3]
#
# 사용자로부터 여러 개의 숫자를 입력받아 리스트에 저장한 후, 사용자가 'done'이라고 입력할 때까지 계속 입력받으세요.
#
# - 입력 중 숫자가 아닌 값이 입력되면 ValueError를 처리
# - 숫자 외 값이 입력된 경우 어떤 값이 잘못 입력되었는지 사용자에게 알려주는 문구 출력<br>
#   (예: f"잘못된 값: {변수}. 숫자를 입력해주세요.")

# %%
list = []
while True:
    num = input('숫자를 입력하세요.')
    if num == 'done':
        break
    try:
        list.append(int(num))
    except ValueError:
        print(f"잘못된 값: {num}. 숫자를 입력하세요.")

print(list)
# Out:
# 숫자를 입력하세요.1
# 숫자를 입력하세요.4
# 숫자를 입력하세요.3
# 숫자를 입력하세요.2
# 숫자를 입력하세요.1
# 숫자를 입력하세요.4
# 숫자를 입력하세요.doen
# 잘못된 값: doen. 숫자를 입력하세요.
# 숫자를 입력하세요.done
# [1, 4, 3, 2, 1, 4]

# %% [markdown]
# ---

# %% [markdown]
# [문제 4]
#
# 사용자 정의 예외 NegativeNumberError를 생성하고, 사용자로부터 숫자를 입력받아 음수일 경우 NegativeNumberError를 발생시키는 프로그램을 작성하세요.
#
# - 예외 처리 구문을 사용하여 음수 입력 시 "양수를 입력해주세요."라는 메시지를 출력

# %%
class NegativeNumberError(Exception):
    pass

try:
    num = float(input("숫자를 입력하세요: "))

    if num < 0:
        raise NegativeNumberError

except NegativeNumberError as e:
    print("양수를 입력해주세요.")
# Out:
# 숫자를 입력하세요: -3
# 양수를 입력해주세요.

# %% [markdown]
# ---

# %% [markdown]
# [문제 5]
#
# datetime 모듈을 사용하여 현재 날짜와 시간을 출력하는 프로그램을 작성하세요.
#
# 또한, 사용자로부터 태어난 년도를 입력받아 현재 나이를 계산하여 출력하세요.

# %%
from datetime import datetime as dt

print(f"현재날짜:{dt.now()}")

birthday = dt.now().year - int(input())

print(f'내 나이는 만으로 {birthday}살이야')
# Out:
# 현재날짜:2025-11-27 07:14:04.361375
# 1995
# 내 생일은 만으로 30살이야

# %% [markdown]
# ---

# %% [markdown]
# [문제 6]
#
# requests 모듈을 사용하여, 웹 페이지의 HTML을 가져오는 간단한 웹 스크레이퍼를 작성하세요.
#
# 'https://kream.co.kr/'에서<br>
# 데이터를 가져와서 상태 코드와 HTML의 첫 100자를 출력하세요.<br>
# (실습 전 requests 모듈을 설치해야 함)

# %%
import requests as rq

print(rq.get('https://kream.co.kr/'))
# Out:
# <Response [500]>

# %% [markdown]
# ---

# %% [markdown]
# [문제 7]
#
# 함수 실행 시간을 측정하는 데코레이터 timer_decorator를 작성하세요.
#
# 임의의 함수가 실행되는 시간을 측정하여 "함수 실행 시간: x.xx초" 형태로 출력하세요.

# %%
import time
# Out:
# 1764228272.6011908

# %% [markdown]
# ---

# %% [markdown]
# [문제 8]
#
# 여러분이 자주 사용하는 수학적 연산<br>
# (예: 삼각형 넓이, 원의 넓이, 직육면체의 넓이)을 수행하는 함수들을 포함하는 mymath.py라는 이름의 모듈을 만드세요.
#
# 이 모듈을 사용하여 작성된 함수들을 실제로 임포트하고 사용하는 간단한 프로그램을 작성하세요.

# %%
# pi = 3.14

# def input_radius():
#     radius = input('반지름 입력')
#     return float(radius)

# def input_height():
#     radius = input('가로 입력')
#     return float(radius)

# def input_length():
#     radius = input('세로 입력')
#     return float(radius)

# def circle(r):
#     return pi * r ** 2

# def triangle(height,length):
#     return height * length / 2

# def rectangle(height,length):
#     return height * length

# %%
import mymath as my

# 원
radius = my.input_radius()
print(my.circle(radius))

# 삼각형
hei = my.input_height()
len = my.input_length()
print(my.triangle(hei,len))

# 사각형
hei = my.input_height()
len = my.input_length()
print(my.rectangle(hei,len))
# Out:
# 반지름 입력6
# 113.04
# 가로 입력3
# 세로 입력7
# 10.5
# 가로 입력2
# 세로 입력7
# 14.0

# %% [markdown]
# ---

# %% [markdown]
# [문제 9]
#
# animals라는 패키지를 만들고, 이 패키지 내에 mammals, birds라는 두 개의 서브 모듈을 생성하세요.
#
# - 각 모듈에는 최소한 한 개 이상의 동물에 관한 클래스를 정의하세요<br>
#   (예: mammals에는 Dog, birds에는 Eagle)
# - 이 패키지와 모듈을 사용하여 동물들의 정보를 출력하는 프로그램을 작성
#
# 폴더 및 파일 구조
# ```
# animals/(폴더)
# ├── __init__.py
# ├── mammals.py
# └── birds.py
# ```

# %%
import importlib
import animal.mammals as mm

importlib.reload(mm)
# Out:
# <module 'animal.mammals' from '/content/animal/mammals.py'>

# %%
class eagle:
    def __init__(self):
        self.info = (
            "깃털을 가진 수각류 공룡으로 백악기 대멸종에서 살아남은 공룡으로 알려져 있다. "
            "새는 현대적 의미의 파충류로 간주되며, 가장 가까운 생물학적 친척은 악어이다."
        )

    def show_info(self):
        print(self.info)

# %%
class dog:
    def __init__(self):
        self.info = "중형 동물이자 가장 널리 분포하며 개체 수가 가장 많은 지상 동물 중 하나이며 가축화된 회색늑대이다."

    def show_info(self):
        print(self.info)

# %%
import animal.mammals as mm
import animal.birds as bd

dog = mm.dog()
eagle = bd.eagle()

dog.show_info()
eagle.show_info()
# Out:
# 중형 동물이자 가장 널리 분포하며 개체 수가 가장 많은 지상 동물 중 하나이며 가축화된 회색늑대이다.
# 깃털을 가진 수각류 공룡으로 백악기 대멸종에서 살아남은 공룡으로 알려져 있다. 새는 현대적 의미의 파충류로 간주되며, 가장 가까운 생물학적 친척은 악어이다.

# %% [markdown]
# ---
