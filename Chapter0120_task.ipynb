# %% [markdown]
# <a href="https://colab.research.google.com/github/HHJina/oz_python/blob/main/Chapter0120_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter17 ~ 20 수업은 잘 들으셨나요?
#
# Chapter01 ~ 20의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# 저번에 했던 "붕어빵 자동 판매 시스템"을 리팩토링 해봅시다 !!!
#
# 못해도 괜찮아요 ! 같이 해봅시다 !
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ### 리팩토링 과제
#
# Day4에서 만든 "붕어빵 자동 판매 시스템"은 절차적 코드로 구현되어있습니다.
# <br>
#
# Day5에서 배운 함수, 클래스 개념을 적용시켜 객체지향적으로 리팩토링을 진행해주세요

# %%
# 리팩토링 과제 힌트
# 구조는 아래와 같습니다.
class BungeoppangShop:
    def __init__(self):

    def check_stock(self):

    def process_order(self, bread_type, bread_count):

    def admin_mode(self):

    def calculate_total_sales(self):

def main():

if __name__ == "__main__":
    main()

# %% [markdown]
# __BungeoppangShop 클래스__
#
# - __init__(): 초기 재고, 가격, 판매량을 설정합니다.
# - check_stock(): 현재 재고를 출력합니다.
# - process_order(): 주문을 처리하고 재고를 업데이트합니다.
# - admin_mode(): 관리자 모드에서 재고를 추가합니다.
# - calculate_total_sales(): 총 매출을 계산하고 출력합니다.

# %% [markdown]
# __[과제 1: 초기화 메서드 __init__]__
#
# 목표: __init__ 메서드를 구현하여 붕어빵 가게의 초기 재고, 가격, 판매량을 설정합니다.
#
# 설명: self.stock, self.prices, self.sales 딕셔너리를 초기화하세요.
# - stock
#     - "팥붕어빵": 10
#     - "슈크림붕어빵": 8
#     - "초코붕어빵": 5
#
# - prices
#     - "팥붕어빵": 1000
#     - "슈크림붕어빵": 1200
#     - "초코붕어빵": 1500
#
# - sales
#     - "팥붕어빵": 0,
#     - "슈크림붕어빵": 0,
#     - "초코붕어빵": 0

# %%
class BungeoppangShop:
    def __init__(self):
        self.stock = {"팥불어빵":10, "슈크림붕어빵":8, "초코붕어빵":5}
        self.prices = {"팥불어빵":1000, "슈크림붕어빵":1200, "초코붕어빵":1500}
        self.sales = {"팥불어빵":0, "슈크림붕어빵":0, "초코붕어빵":0}
    # def check_stock(self):

    # def process_order(self, bread_type, bread_count):

    # def admin_mode(self):

    # def calculate_total_sales(self):

# def main():

# if __name__ == "__main__":
#     main()

# %% [markdown]
# __[과제 2: 재고 확인 메서드 check_stock]__
#
# 목표: check_stock 함수를 구현하여 현재 붕어빵 재고를 출력합니다.
#
# 설명: self.stock 딕셔너리를 순회하며 각 붕어빵의 종류와 재고를 출력하세요.

# %%
class BungeoppangShop:
    def __init__(self):
        self.stock = {"팥붕어빵":10, "슈크림붕어빵":8, "초코붕어빵":5}
        self.prices = {"팥붕어빵":1000, "슈크림붕어빵":1200, "초코붕어빵":1500}
        self.sales = {"팥붕어빵":0, "슈크림붕어빵":0, "초코붕어빵":0}
    def check_stock(self):
        for key,val in self.stock.items():
            print(f"{key}:{val}개")
    # def process_order(self, bread_type, bread_count):

    # def admin_mode(self):

    # def calculate_total_sales(self):

def main():
    oz = BungeoppangShop()
    oz.check_stock();

if __name__ == "__main__":
    main()
# Out:
# 팥붕어빵:10개
# 슈크림붕어빵:8개
# 초코붕어빵:5개

# %% [markdown]
# __[과제 3: 주문 처리 메서드 process_order]__
#
# 목표: process_order 함수를 구현하여 손님의 주문을 처리하고 재고를 업데이트합니다.
#
# 설명: bread_type과 bread_count를 매개변수로 받아, 재고를 확인하고 충분한 경우 재고를 감소시키고 판매량을 증가시킵니다. 재고가 부족하거나 잘못된 붕어빵 종류인 경우 적절한 메시지를 출력하세요.

# %%
class BungeoppangShop:
    def __init__(self):
        self.stock = {"팥붕어빵":10, "슈크림붕어빵":8, "초코붕어빵":5}
        self.prices = {"팥붕어빵":1000, "슈크림붕어빵":1200, "초코붕어빵":1500}
        self.sales = {"팥붕어빵":0, "슈크림붕어빵":0, "초코붕어빵":0}
    def check_stock(self):
        for key,val in self.stock.items():
            print(f"{key}:{val}개")
    def process_order(self, bread_type, bread_count):
        try:
            if bread_type not in self.stock:
                print(f"'{bread_type}'는 판매하지 않는 붕어빵입니다. 다시 입력해주세요.")
                return

            count = int(bread_count)

            if self.stock[bread_type] < count:
                print(f"현재 {bread_type} 재고가 부족합니다. 재고({self.stock[bread_type]})")
                return

            # 차감
            self.stock[bread_type] -= count
            print(self.stock, "재고량")

            # 판매량 증가
            self.sales[bread_type] += count
            print(self.sales, "판매량")

        except :
            # 숫자 변환 실패
            print("개수는 숫자로 입력해야 합니다.")


    # def admin_mode(self):

    # def calculate_total_sales(self):

def main():
    oz = BungeoppangShop()
    # oz.check_stock(); //재고
    bread_type, bread_count = input("붕어빵 종류와 개수를 콤마(,)로 구분해서 입력하세요").split(',')
    oz.process_order(bread_type,bread_count)

if __name__ == "__main__":
    main()
# Out:
# 붕어빵 종류와 개수를 콤마(,)로 구분해서 입력하세요팥붕어빵,ㅁㄴㅇ
# 개수는 숫자로 입력해야 합니다.

# %% [markdown]
# __[과제 4: 관리자 모드 메서드 admin_mode]__
#
# 목표: admin_mode 메서드를 구현하여 관리자 모드에서 재고를 추가할 수 있도록 합니다.
#
# 설명: bread_type과 additional_stock을 입력받아 재고를 추가합니다. 잘못된 입력 값이 들어온 경우 적절한 메시지를 출력하세요.

# %%
class BungeoppangShop:
    def __init__(self):
        self.stock = {"팥붕어빵":10, "슈크림붕어빵":8, "초코붕어빵":5}
        self.prices = {"팥붕어빵":1000, "슈크림붕어빵":1200, "초코붕어빵":1500}
        self.sales = {"팥붕어빵":0, "슈크림붕어빵":0, "초코붕어빵":0}
    def check_stock(self):
        for key,val in self.stock.items():
            print(f"{key}:{val}개")
    def process_order(self, bread_type, bread_count):
        try:
            if bread_type not in self.stock:
                print(f"'{bread_type}'는 판매하지 않는 붕어빵입니다. 다시 입력해주세요.")
                return

            count = int(bread_count)

            if self.stock[bread_type] < count:
                print(f"현재 {bread_type} 재고가 부족합니다. 재고({self.stock[bread_type]})")
                return

            # 차감
            self.stock[bread_type] -= count
            print(self.stock, "재고량")

            # 판매량 증가
            self.sales[bread_type] += count
            print(self.sales, "판매량")

        except :
            # 숫자 변환 실패
            print("개수는 숫자로 입력해야 합니다.")


    def admin_mode(self,bread_type,additional_stock):
        try:
            if bread_type not in self.stock:
                print(f"'{bread_type}'는 판매하지 않는 붕어빵입니다. 다시 입력해주세요.")
                return

            count = int(additional_stock)

            # 증가
            self.stock[bread_type] += count
            print(self.stock, "재고량")

        except :
            # 숫자 변환 실패
            print("개수는 숫자로 입력해야 합니다.")

    # def calculate_total_sales(self):

def main():
    oz = BungeoppangShop()
    # oz.check_stock(); //재고
    bread_type, bread_count = input("붕어빵 종류와 개수를 콤마(,)로 구분해서 입력하세요").split(',')
    # oz.process_order(bread_type,bread_count) //판매
    oz.admin_mode(bread_type,bread_count)

if __name__ == "__main__":
    main()
# Out:
# 붕어빵 종류와 개수를 콤마(,)로 구분해서 입력하세요팥붕어빵,10
# {'팥붕어빵': 20, '슈크림붕어빵': 8, '초코붕어빵': 5} 재고량

# %% [markdown]
# __[과제 5: 매출 계산 메서드 calculate_total_sales]__
#
# 목표: calculate_total_sales 메서드를 구현하여 총 매출을 계산하고 출력합니다.
#
# 설명: self.sales와 self.prices를 사용하여 총 매출을 계산하고 출력하세요.

# %%
class BungeoppangShop:
    def __init__(self):
        self.stock = {"팥붕어빵":10, "슈크림붕어빵":8, "초코붕어빵":5}
        self.prices = {"팥붕어빵":1000, "슈크림붕어빵":1200, "초코붕어빵":1500}
        self.sales = {"팥붕어빵":2, "슈크림붕어빵":0, "초코붕어빵":5}
    def check_stock(self):
        for key,val in self.stock.items():
            print(f"{key}:{val}개")
    def process_order(self, bread_type, bread_count):
        try:
            if bread_type not in self.stock:
                print(f"'{bread_type}'는 판매하지 않는 붕어빵입니다. 다시 입력해주세요.")
                return

            count = int(bread_count)

            if self.stock[bread_type] < count:
                print(f"현재 {bread_type} 재고가 부족합니다. 재고({self.stock[bread_type]})")
                return

            # 차감
            self.stock[bread_type] -= count
            print(self.stock, "재고량")

            # 판매량 증가
            self.sales[bread_type] += count
            print(self.sales, "판매량")

        except :
            # 숫자 변환 실패
            print("개수는 숫자로 입력해야 합니다.")


    def admin_mode(self,bread_type,additional_stock):
        try:
            if bread_type not in self.stock:
                print(f"'{bread_type}'는 판매하지 않는 붕어빵입니다. 다시 입력해주세요.")
                return

            count = int(additional_stock)

            # 증가
            self.stock[bread_type] += count
            print(self.stock, "재고량")

        except :
            # 숫자 변환 실패
            print("개수는 숫자로 입력해야 합니다.")

    def calculate_total_sales(self):
        sum = 0
        for key,val in self.sales.items() :
            sum += val * self.prices.get(key)
        print(f"오늘 총 {sum}원 팔았어요.")

def main():
    oz = BungeoppangShop()
    # oz.check_stock(); //재고
    # bread_type, bread_count = input("붕어빵 종류와 개수를 콤마(,)로 구분해서 입력하세요").split(',')
    # oz.process_order(bread_type,bread_count) //판매
    # oz.admin_mode(bread_type,bread_count) //관리자
    oz.calculate_total_sales()

if __name__ == "__main__":
    main()
# Out:
# 오늘 총 9500원 팔았어요.

# %% [markdown]
# __[과제 6: 메인 함수 main]__
#
# 목표: main 함수를 작성하여 프로그램의 주요 로직을 실행합니다.
#
# 설명:
# - BungeoppangShop 객체를 생성합니다.
# - 사용자에게 모드를 선택하도록 요청합니다.
# - "주문" 모드에서는 손님의 주문을 처리하고, "관리자" 모드에서는 재고를 추가할 수 있습니다.
# - 프로그램이 종료될 때 총 매출을 계산하고 데이터를 저장합니다.

# %%
class BungeoppangShop:
    def __init__(self):
        self.stock = {"팥붕어빵":10, "슈크림붕어빵":8, "초코붕어빵":5}
        self.prices = {"팥붕어빵":1000, "슈크림붕어빵":1200, "초코붕어빵":1500}
        self.sales = {"팥붕어빵":0, "슈크림붕어빵":0, "초코붕어빵":0}
    def check_stock(self):
        for key,val in self.stock.items():
            print(f"{key}:{val}개")
    def process_order(self, bread_type, bread_count):
        try:
            if bread_type not in self.stock:
                print(f"'{bread_type}'는 판매하지 않는 붕어빵입니다. 다시 입력해주세요.")
                return

            count = int(bread_count)

            if self.stock[bread_type] < count:
                print(f"현재 {bread_type} 재고가 부족합니다. 재고({self.stock[bread_type]})")
                return

            # 차감
            self.stock[bread_type] -= count
            print(self.stock, "재고량")

            # 판매량 증가
            self.sales[bread_type] += count
            print(self.sales, "판매량")

        except :
            # 숫자 변환 실패
            print("개수는 숫자로 입력해야 합니다.")


    def admin_mode(self,bread_type,additional_stock):
        try:
            if bread_type not in self.stock:
                print(f"'{bread_type}'는 판매하지 않는 붕어빵입니다. 다시 입력해주세요.")
                return

            count = int(additional_stock)

            # 증가
            self.stock[bread_type] += count
            print(self.stock, "재고량")

        except :
            # 숫자 변환 실패
            print("개수는 숫자로 입력해야 합니다.")

    def calculate_total_sales(self):
        sum = 0
        for key,val in self.sales.items() :
            sum += val * self.prices.get(key)
        print(f"오늘 총 {sum}원 팔았어요.")

def main():
    shop = BungeoppangShop()

    while True :
        print("모드를 선택하세요:")
        print("1. 주문 처리")
        print("2. 관리자 모드")
        print("3. 종료")

        mode = input("번호를 입력하세요: ")

        if mode == "1" :
            bread_type, bread_count = input("붕어빵 종류와 개수를 입력하세요: ").split(',')
            shop.process_order(bread_type, bread_count)

        elif mode == "2" :
            bread_type, add_stock = input("추가할 종류와 수량을 입력하세요: ").split(',')
            shop.admin_mode(bread_type, add_stock)

        elif mode == "3" :
            shop.calculate_total_sales()
            print("종료합니다")
            break

        else:
            print("잘못 입력하셨습니다. 번호(1~3) 중 하나를 선택해주세요.")

if __name__ == "__main__":
    main()

# %% [markdown]
# __[과제 7: 최종 BungeoppangShop 클래스]__
#
# 함수로 리팩토링한 "붕어빵 자동 판매 시스템" 작성 후 실행합니다.

# %%
class BungeoppangShop:
    def __init__(self):
        self.stock = {"팥붕어빵":10, "슈크림붕어빵":8, "초코붕어빵":5}
        self.prices = {"팥붕어빵":1000, "슈크림붕어빵":1200, "초코붕어빵":1500}
        self.sales = {"팥붕어빵":0, "슈크림붕어빵":0, "초코붕어빵":0}
    def check_stock(self):
        for key,val in self.stock.items():
            print(f"{key}:{val}개")
    def process_order(self, bread_type, bread_count):
        try:
            if bread_type not in self.stock:
                print(f"'{bread_type}'는 판매하지 않는 붕어빵입니다. 다시 입력해주세요.")
                return

            count = int(bread_count)

            if self.stock[bread_type] < count:
                print(f"현재 {bread_type} 재고가 부족합니다. 재고({self.stock[bread_type]})")
                return

            # 차감
            self.stock[bread_type] -= count
            print(self.stock, "재고량")

            # 판매량 증가
            self.sales[bread_type] += count
            print(self.sales, "판매량")

        except :
            # 숫자 변환 실패
            print("개수는 숫자로 입력해야 합니다.")


    def admin_mode(self,bread_type,additional_stock):
        try:
            if bread_type not in self.stock:
                print(f"'{bread_type}'는 판매하지 않는 붕어빵입니다. 다시 입력해주세요.")
                return

            count = int(additional_stock)

            # 증가
            self.stock[bread_type] += count
            print(self.stock, "재고량")

        except :
            # 숫자 변환 실패
            print("개수는 숫자로 입력해야 합니다.")

    def calculate_total_sales(self):
        sum = 0
        for key,val in self.sales.items() :
            sum += val * self.prices.get(key)
        print(f"오늘 총 {sum}원 팔았어요.")

def main():
    shop = BungeoppangShop()

    while True :
        print("모드를 선택하세요:")
        print("1. 주문 처리")
        print("2. 관리자 모드")
        print("3. 종료")

        mode = input("번호를 입력하세요: ")

        if mode == "1" :
            bread_type, bread_count = input("붕어빵 종류와 개수를 입력하세요: ").split(',')
            shop.process_order(bread_type, bread_count)

        elif mode == "2" :
            bread_type, add_stock = input("추가할 종류와 수량을 입력하세요: ").split(',')
            shop.admin_mode(bread_type, add_stock)

        elif mode == "3" :
            shop.calculate_total_sales()
            print("종료합니다")
            break

        else:
            print("잘못 입력하셨습니다. 번호(1~3) 중 하나를 선택해주세요.")

if __name__ == "__main__":
    main()
# Out:
# 모드를 선택하세요:
# 1. 주문 처리
# 2. 관리자 모드
# 3. 종료
# 번호를 입력하세요: 1
# 붕어빵 종류와 개수를 입력하세요: 팥붕어빵,5
# {'팥붕어빵': 5, '슈크림붕어빵': 8, '초코붕어빵': 5} 재고량
# {'팥붕어빵': 5, '슈크림붕어빵': 0, '초코붕어빵': 0} 판매량
# 모드를 선택하세요:
# 1. 주문 처리
# 2. 관리자 모드
# 3. 종료
# 번호를 입력하세요: 2
# 추가할 종류와 수량을 입력하세요: 팥붕어빵,5
# {'팥붕어빵': 10, '슈크림붕어빵': 8, '초코붕어빵': 5} 재고량
# 모드를 선택하세요:
# 1. 주문 처리
# 2. 관리자 모드
# 3. 종료
# 번호를 입력하세요: 팥붕어빵,12
# 잘못 입력하셨습니다. 번호(1~3) 중 하나를 선택해주세요.
# 모드를 선택하세요:
# 1. 주문 처리
# 2. 관리자 모드
# 3. 종료
# 번호를 입력하세요: 1
# 붕어빵 종류와 개수를 입력하세요: 팥붕어빵,12
# 현재 팥붕어빵 재고가 부족합니다. 재고(10)
# 모드를 선택하세요:
# 1. 주문 처리
# 2. 관리자 모드
# 3. 종료
# 번호를 입력하세요: 1
# 붕어빵 종류와 개수를 입력하세요: 초코붕어빵,5
# {'팥붕어빵': 10, '슈크림붕어빵': 8, '초코붕어빵': 0} 재고량
# {'팥붕어빵': 5, '슈크림붕어빵': 0, '초코붕어빵': 5} 판매량
# 모드를 선택하세요:
# 1. 주문 처리
# 2. 관리자 모드
# 3. 종료
# 번호를 입력하세요: 2
# 추가할 종류와 수량을 입력하세요: 슈크림붕어빵,4
# {'팥붕어빵': 10, '슈크림붕어빵': 12, '초코붕어빵': 0} 재고량
# 모드를 선택하세요:
# 1. 주문 처리
# 2. 관리자 모드
# 3. 종료
# 번호를 입력하세요: 3
# 오늘 총 12500원 팔았어요.
# 종료합니다
